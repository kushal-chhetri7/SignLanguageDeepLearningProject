# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras import  models,layers
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
image_size = 224
channels = 3

# %%
training_data = ImageDataGenerator(
    rescale = 1.0/255,
    horizontal_flip=True,
    rotation_range = 10


)

train_gen = training_data.flow_from_directory(
    'data_set/train',
    target_size = (image_size,image_size),
    batch_size = 16,
    class_mode = 'sparse'
    

)
# Out:
# Found 1680 images belonging to 7 classes.

# %%
val_data = ImageDataGenerator(
    rescale = 1.0 / 255,
    horizontal_flip= True,
    rotation_range= 10,
    

)

val_gen = val_data.flow_from_directory(
    'data_set/val',
    target_size=(image_size,image_size),
    batch_size=16,
    class_mode='sparse'

)
# Out:
# Found 210 images belonging to 7 classes.

# %%
test_data = ImageDataGenerator(
    rescale=1.0/255,
    horizontal_flip=True,
    rotation_range=10

)
test_gen = test_data.flow_from_directory(
    'data_set/test',
    target_size=(image_size, image_size),
    batch_size = 16,
    class_mode='sparse'
)
# Out:
# Found 210 images belonging to 7 classes.

# %%
print(train_gen.class_indices)
# Out:
# {'Dislike-samples': 0, 'Livelong-samples': 1, 'Love-samples': 2, 'Peace-samples': 3, 'like-samples': 4, 'okay-samples': 5, 'unknown-samples': 6}

# %%
class_names = list(train_gen.class_indices.keys())
class_names
# Out:
# ['Dislike-samples',
#  'Livelong-samples',
#  'Love-samples',
#  'Peace-samples',
#  'like-samples',
#  'okay-samples',
#  'unknown-samples']

# %%
input_shape = (image_size,image_size,channels)
class_labels = 7

model = models.Sequential([
    
    layers.InputLayer(input_shape = input_shape),
    # first layers of cnn
    layers.Conv2D(32,(3,3), activation = 'relu', input_shape = input_shape),
    layers.MaxPooling2D((2,2)),
    # second layers of cnn
    layers.Conv2D(64, kernel_size = (3,3), activation = 'relu'),
    layers.MaxPooling2D((2,2)),
    
    # third layers of cnn
    layers.Conv2D(64,(3,3), activation='relu'),
    layers.MaxPooling2D((2,2)),
    
    #fouth layers of cnn
    layers.Conv2D(64,(3,3),activation='relu'),
    layers.MaxPooling2D((2,2)),
    
    #flatten layers
    layers.Flatten(),
    
    #dense layers
    layers.Dense(64, activation= 'relu'),
    
    #out put layers
    layers.Dense(class_labels, activation='softmax'),
    
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 64)        36928
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 64)        36928
#
#  max_pooling2d_3 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 64)                589888
#
#  dense_1 (Dense)             (None, 7)                 455
#
# =================================================================
# Total params: 683,591
# Trainable params: 683,591
# Non-trainable params: 0
# _________________________________________________________________

# %%
#hyperparameters
model.compile(
    optimizer='adam',
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']


)

# %%
#  print(steps_per_epoch)

# %%
history = model.fit(
    
    
    train_gen,
    steps_per_epoch= 30,
    batch_size=16,
    validation_data=val_gen,
    validation_steps=7,
    verbose = 1,
    epochs = 50
        
    

)
# Out:
# Epoch 1/50
# 30/30 [==============================] - 20s 656ms/step - loss: 1.9578 - accuracy: 0.2146 - val_loss: 1.9170 - val_accuracy: 0.4107
# Epoch 2/50
# 30/30 [==============================] - 19s 619ms/step - loss: 1.4756 - accuracy: 0.4542 - val_loss: 0.9652 - val_accuracy: 0.5982
# Epoch 3/50
# 30/30 [==============================] - 18s 612ms/step - loss: 0.9036 - accuracy: 0.6521 - val_loss: 0.7477 - val_accuracy: 0.7589
# Epoch 4/50
# 30/30 [==============================] - 18s 610ms/step - loss: 0.7365 - accuracy: 0.7146 - val_loss: 0.6494 - val_accuracy: 0.7500
# Epoch 5/50
# 30/30 [==============================] - 18s 595ms/step - loss: 0.6035 - accuracy: 0.7312 - val_loss: 0.7211 - val_accuracy: 0.6964
# Epoch 6/50
- val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 28/50
# 30/30 [==============================] - 18s 608ms/step - loss: 0.0180 - accuracy: 0.9937 - val_loss: 0.0565 - val_accuracy: 0.9911
# Epoch 29/50
# 30/30 [==============================] - 18s 591ms/step - loss: 0.0260 - accuracy: 0.9937 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 30/50
# 30/30 [==============================] - 18s 595ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 31/50
# 30/30 [==============================] - 18s 589ms/step - loss: 0.0093 - accuracy: 0.9979 - val_loss: 0.0190 - val_accuracy: 0.9911
# Epoch 32/50
# 30/30 [==============================] - 19s 629ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 5.7218e-04 - val_accuracy: 1.0000
# Epoch 33/50
# 30/30 [==============================] - 19s 634ms/step - loss: 0.0096 - accuracy: 0.9979 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 34/50
# 30/30 [==============================] - 18s 603ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 4.6196e-04 - val_accuracy: 1.0000
# Epoch 35/50
# 30/30 [==============================] - 24s 797ms/step - loss: 0.0048 - accuracy: 0.9958 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 36/50
# 30/30 [==============================] - 23s 753ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 5.4523e-04 - val_accuracy: 1.0000
# Epoch 37/50
# 30/30 [==============================] - 22s 745ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 38/50
# 30/30 [==============================] - 22s 728ms/step - loss: 0.0065 - accuracy: 0.9979 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 39/50
# 30/30 [==============================] - 18s 609ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 40/50
# 30/30 [==============================] - 28s 957ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 41/50
# 30/30 [==============================] - 42s 1s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 0.9911
# Epoch 42/50
# 30/30 [==============================] - 37s 1s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 9.4331e-05 - val_accuracy: 1.0000
# Epoch 43/50
# 30/30 [==============================] - 18s 583ms/step - loss: 0.0020 - accuracy: 0.9979 - val_loss: 0.0111 - val_accuracy: 0.9911
# Epoch 44/50
# 30/30 [==============================] - 18s 584ms/step - loss: 0.0329 - accuracy: 0.9917 - val_loss: 0.0539 - val_accuracy: 0.9911
# Epoch 45/50
# 30/30 [==============================] - 18s 588ms/step - loss: 0.0382 - accuracy: 0.9875 - val_loss: 0.0664 - val_accuracy: 0.9821
# Epoch 46/50
# 30/30 [==============================] - 18s 583ms/step - loss: 0.0164 - accuracy: 0.9958 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 47/50
# 30/30 [==============================] - 18s 583ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 7.7461e-04 - val_accuracy: 1.0000
# Epoch 48/50
# 30/30 [==============================] - 18s 588ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 49/50
# 30/30 [==============================] - 18s 593ms/step - loss: 5.9931e-04 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 50/50
# 30/30 [==============================] - 18s 591ms/step - loss: 6.2425e-04 - accuracy: 1.0000 - val_loss: 4.7874e-04 - val_accuracy: 1.0000

# %%
 score = model.evaluate(test_gen)
# Out:
# 14/14 [==============================] - 4s 271ms/step - loss: 2.4932e-04 - accuracy: 1.0000

# %%
 score = model.evaluate(train_gen)
# Out:
# 105/105 [==============================] - 28s 268ms/step - loss: 8.8508e-04 - accuracy: 1.0000

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']


loss = history.history['loss']
val_loss = history.history['val_loss']


epochs = 50
plt.figure(figsize= (8,8))
plt.subplot(1,2,1)
plt.plot(range(epochs), acc, label = 'Training Accuracy')
plt.plot(range(epochs),val_acc, label = 'Validation Accuracy')
plt.legend(loc = 'lower right')
plt.title('Training vs Validation accuracy')

plt.subplot(1,2,2)
plt.plot(range(epochs), loss, label = 'Loss')
plt.plot(range(epochs),val_loss,label = 'Validation loss')
plt.title('Loss vs Validation loss')
# Out:
# Text(0.5, 1.0, 'Loss vs Validation loss')

# %%
import numpy as np


for image_batch, label_batch in test_gen:
    first_image = image_batch[0]
    first_label = int(label_batch[0])
    
    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_names[first_label])
    
    batch_prediction = model.predict(image_batch)
    print("predicted label:",class_names[np.argmax(batch_prediction[0])])
    plt.axis('off')
    
    break
# Out:
# first image to predict
# actual label: okay-samples
# predicted label: okay-samples

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i])
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_gen:
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i])
        
        predicted_class, confidence = predict(model, images[i])
        actual_class = class_names[int(labels[i])] 
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        
        plt.axis("off")
    break

# %%
model.save('Sign_language_classification.h5')
