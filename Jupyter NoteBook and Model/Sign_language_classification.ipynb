# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras import  models,layers
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
image_size = 224
channels = 3

# %%
training_data = ImageDataGenerator(
    rescale = 1.0/255,
    horizontal_flip=True,
    rotation_range = 10


)

train_gen = training_data.flow_from_directory(
    'data_set/train',
    target_size = (image_size,image_size),
    batch_size = 16,
    class_mode = 'sparse'
    

)
# Out:
# Found 1680 images belonging to 7 classes.

# %%
val_data = ImageDataGenerator(
    rescale = 1.0 / 255,
    horizontal_flip= True,
    rotation_range= 10,
    

)

val_gen = val_data.flow_from_directory(
    'data_set/val',
    target_size=(image_size,image_size),
    batch_size=16,
    class_mode='sparse'

)
# Out:
# Found 210 images belonging to 7 classes.

# %%
test_data = ImageDataGenerator(
    rescale=1.0/255,
    horizontal_flip=True,
    rotation_range=10

)
test_gen = test_data.flow_from_directory(
    'data_set/test',
    target_size=(image_size, image_size),
    batch_size = 16,
    class_mode='sparse'
)
# Out:
# Found 210 images belonging to 7 classes.

# %%
print(train_gen.class_indices)
# Out:
# {'Dislike-samples': 0, 'Livelong-samples': 1, 'Love-samples': 2, 'Peace-samples': 3, 'like-samples': 4, 'okay-samples': 5, 'unknown-samples': 6}

# %%
class_names = list(train_gen.class_indices.keys())
class_names
# Out:
# ['Dislike-samples',
#  'Livelong-samples',
#  'Love-samples',
#  'Peace-samples',
#  'like-samples',
#  'okay-samples',
#  'unknown-samples']

# %%
input_shape = (image_size,image_size,channels)
class_labels = 7

model = models.Sequential([
    
    layers.InputLayer(input_shape = input_shape),
    # first layers of cnn
    layers.Conv2D(32,(3,3), activation = 'relu', input_shape = input_shape),
    layers.MaxPooling2D((2,2)),
    # second layers of cnn
    layers.Conv2D(64, kernel_size = (3,3), activation = 'relu'),
    layers.MaxPooling2D((2,2)),
    
    # third layers of cnn
    layers.Conv2D(64,(3,3), activation='relu'),
    layers.MaxPooling2D((2,2)),
    
    #fouth layers of cnn
    layers.Conv2D(64,(3,3),activation='relu'),
    layers.MaxPooling2D((2,2)),
    
    #flatten layers
    layers.Flatten(),
    
    #dense layers
    layers.Dense(64, activation= 'relu'),
    
    #out put layers
    layers.Dense(class_labels, activation='softmax'),
    
])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 222, 222, 32)      896
#
#  max_pooling2d_12 (MaxPoolin  (None, 111, 111, 32)     0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 109, 109, 64)      18496
#
#  max_pooling2d_13 (MaxPoolin  (None, 54, 54, 64)       0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 52, 52, 64)        36928
#
#  max_pooling2d_14 (MaxPoolin  (None, 26, 26, 64)       0
#  g2D)
#
#  conv2d_15 (Conv2D)          (None, 24, 24, 64)        36928
#
#  max_pooling2d_15 (MaxPoolin  (None, 12, 12, 64)       0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 9216)              0
#
#  dense_6 (Dense)             (None, 64)                589888
#
#  dense_7 (Dense)             (None, 7)                 455
#
# =================================================================
# Total params: 683,591
# Trainable params: 683,591
# Non-trainable params: 0
# _________________________________________________________________

# %%
#hyperparameters
model.compile(
    optimizer='adam',
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']


)

# %%
#  print(steps_per_epoch)

# %%
history = model.fit(
    
    
    train_gen,
    steps_per_epoch= 30,
    batch_size=16,
    validation_data=val_gen,
    validation_steps=7,
    verbose = 1,
    epochs = 50
        
    

)
# Out:
# Epoch 1/50
# 30/30 [==============================] - 14s 445ms/step - loss: 1.8027 - accuracy: 0.2396 - val_loss: 1.2531 - val_accuracy: 0.5625
# Epoch 2/50
# 30/30 [==============================] - 13s 437ms/step - loss: 0.9403 - accuracy: 0.6250 - val_loss: 0.9491 - val_accuracy: 0.5804
# Epoch 3/50
# 30/30 [==============================] - 13s 439ms/step - loss: 0.6923 - accuracy: 0.7104 - val_loss: 0.6570 - val_accuracy: 0.7857
# Epoch 4/50
# 30/30 [==============================] - 13s 439ms/step - loss: 0.7375 - accuracy: 0.7146 - val_loss: 0.5148 - val_accuracy: 0.8036
# Epoch 5/50
# 30/30 [==============================] - 13s 439ms/step - loss: 0.6244 - accuracy: 0.7583 - val_loss: 0.4843 - val_accuracy: 0.9018
# Epoch 6/50
# 30/30 [==============================] - 13s 445ms/step - loss: 0.5618 - accuracy: 0.8229 - val_loss: 0.6476 - val_accuracy: 0.7589
# Epoch 7/50
# 30/30 [==============================] - 14s 452ms/step - loss: 0.3967 - accuracy: 0.8583 - val_loss: 2.9747 - val_accuracy: 0.4375
# Epoch 8/50
# 30/30 [==============================] - 14s 459ms/step - loss: 0.9442 - accuracy: 0.7083 - val_loss: 0.8901 - val_accuracy: 0.6518
# Epoch 9/50
# 30/30 [==============================] - 14s 455ms/step - loss: 0.6804 - accuracy: 0.7437 - val_loss: 0.4093 - val_accuracy: 0.8214
# Epoch 10/50
# 30/30 [==============================] - 14s 453ms/step - loss: 0.4424 - accuracy: 0.8375 - val_loss: 0.3304 - val_accuracy: 0.8482
# Epoch 11/50
# 30/30 [==============================] - 14s 455ms/step - loss: 0.3763 - accuracy: 0.8833 - val_loss: 0.1906 - val_accuracy: 0.9464
# Epoch 12/50
# 30/30 [==============================] - 14s 451ms/step - loss: 0.2695 - accuracy: 0.9208 - val_loss: 0.2847 - val_accuracy: 0.9196
# Epoch 13/50
# 30/30 [==============================] - 14s 471ms/step - loss: 0.2032 - accuracy: 0.9333 - val_loss: 0.2008 - val_accuracy: 0.9018
# Epoch 14/50
# 30/30 [==============================] - 14s 452ms/step - loss: 0.1541 - accuracy: 0.9521 - val_loss: 0.0854 - val_accuracy: 0.9821
# Epoch 15/50
# 30/30 [==============================] - 13s 448ms/step - loss: 0.1993 - accuracy: 0.9375 - val_loss: 0.0906 - val_accuracy: 0.9911
# Epoch 16/50
# 30/30 [==============================] - 14s 450ms/step - loss: 0.0906 - accuracy: 0.9708 - val_loss: 0.1430 - val_accuracy: 0.9286
# Epoch 17/50
# 30/30 [==============================] - 14s 455ms/step - loss: 0.1280 - accuracy: 0.9625 - val_loss: 0.0887 - val_accuracy: 0.9554
# Epoch 18/50
# 30/30 [==============================] - 14s 456ms/step - loss: 0.1070 - accuracy: 0.9771 - val_loss: 0.0785 - val_accuracy: 0.9732
# Epoch 19/50
# 30/30 [==============================] - 14s 452ms/step - loss: 0.1410 - accuracy: 0.9583 - val_loss: 0.0405 - val_accuracy: 1.0000
# Epoch 20/50
# 30/30 [==============================] - 14s 454ms/step - loss: 0.1061 - accuracy: 0.9688 - val_loss: 0.2547 - val_accuracy: 0.9286
# Epoch 21/50
# 30/30 [==============================] - 14s 454ms/step - loss: 0.0833 - accuracy: 0.9646 - val_loss: 0.0581 - val_accuracy: 0.9821
# Epoch 22/50
# 30/30 [==============================] - 14s 455ms/step - loss: 0.0731 - accuracy: 0.9771 - val_loss: 0.0783 - val_accuracy: 0.9821
# Epoch 23/50
# 30/30 [==============================] - 15s 511ms/step - loss: 0.0495 - accuracy: 0.9917 - val_loss: 0.0396 - val_accuracy: 0.9821
# Epoch 24/50
# 30/30 [==============================] - 14s 477ms/step - loss: 0.0363 - accuracy: 0.9917 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 25/50
# 30/30 [==============================] - 15s 497ms/step - loss: 0.0243 - accuracy: 0.9937 - val_loss: 0.0082 - val_accuracy: 1.0000
# Epoch 26/50
# 30/30 [==============================] - 16s 517ms/step - loss: 0.0317 - accuracy: 0.9875 - val_loss: 0.0319 - val_accuracy: 0.9911
# Epoch 27/50
# 30/30 [==============================] - 16s 542ms/step - loss: 0.0572 - accuracy: 0.9833 - val_loss: 0.0267 - val_accuracy: 0.9911
# Epoch 28/50
# 30/30 [==============================] - 17s 553ms/step - loss: 0.0546 - accuracy: 0.9833 - val_loss: 0.0065 - val_accuracy: 1.0000
# Epoch 29/50
# 30/30 [==============================] - 17s 555ms/step - loss: 0.0528 - accuracy: 0.9896 - val_loss: 0.0180 - val_accuracy: 0.9911
# Epoch 30/50
# 30/30 [==============================] - 17s 558ms/step - loss: 0.0088 - accuracy: 0.9979 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 31/50
# 30/30 [==============================] - 17s 552ms/step - loss: 0.0235 - accuracy: 0.9917 - val_loss: 0.0712 - val_accuracy: 0.9821
# Epoch 32/50
# 30/30 [==============================] - 17s 551ms/step - loss: 0.0183 - accuracy: 0.9958 - val_loss: 0.0153 - val_accuracy: 0.9821
# Epoch 33/50
# 30/30 [==============================] - 16s 544ms/step - loss: 0.0262 - accuracy: 0.9917 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 34/50
# 30/30 [==============================] - 16s 544ms/step - loss: 0.0091 - accuracy: 0.9979 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 35/50
# 30/30 [==============================] - 16s 548ms/step - loss: 0.0065 - accuracy: 0.9979 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 36/50
# 30/30 [==============================] - 16s 549ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 37/50
# 30/30 [==============================] - 17s 570ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 38/50
# 30/30 [==============================] - 18s 593ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 3.2750e-04 - val_accuracy: 1.0000
# Epoch 39/50
# 30/30 [==============================] - 18s 590ms/step - loss: 7.3028e-04 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 40/50
# 30/30 [==============================] - 18s 588ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 9.4310e-04 - val_accuracy: 1.0000
# Epoch 41/50
# 30/30 [==============================] - 18s 595ms/step - loss: 0.0021 - accuracy: 0.9979 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 42/50
# 30/30 [==============================] - 18s 586ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 43/50
# 30/30 [==============================] - 18s 587ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 3.6323e-04 - val_accuracy: 1.0000
# Epoch 44/50
# 30/30 [==============================] - 18s 586ms/step - loss: 8.3275e-04 - accuracy: 1.0000 - val_loss: 2.2504e-04 - val_accuracy: 1.0000
# Epoch 45/50
# 30/30 [==============================] - 18s 586ms/step - loss: 0.0103 - accuracy: 0.9958 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 46/50
# 30/30 [==============================] - 18s 591ms/step - loss: 0.0192 - accuracy: 0.9917 - val_loss: 0.0088 - val_accuracy: 0.9911
# Epoch 47/50
# 30/30 [==============================] - 18s 603ms/step - loss: 0.0152 - accuracy: 0.9979 - val_loss: 0.0216 - val_accuracy: 0.9911
# Epoch 48/50
# 30/30 [==============================] - 18s 596ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 49/50
# 30/30 [==============================] - 18s 600ms/step - loss: 0.0074 - accuracy: 0.9979 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 50/50
# 30/30 [==============================] - 18s 591ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 8.9133e-04 - val_accuracy: 1.0000

# %%
 score = model.evaluate(test_gen)
# Out:
# 14/14 [==============================] - 3s 201ms/step - loss: 0.0027 - accuracy: 1.0000

# %%
 score = model.evaluate(train_gen)
# Out:
# 105/105 [==============================] - 23s 222ms/step - loss: 0.0031 - accuracy: 0.9994

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']


loss = history.history['loss']
val_loss = history.history['val_loss']


epochs = 50
plt.figure(figsize= (8,8))
plt.subplot(1,2,1)
plt.plot(range(epochs), acc, label = 'Training Accuracy')
plt.plot(range(epochs),val_acc, label = 'Validation Accuracy')
plt.legend(loc = 'lower right')
plt.title('Training vs Validation accuracy')

plt.subplot(1,2,2)
plt.plot(range(epochs), loss, label = 'Loss')
plt.plot(range(epochs),val_loss,label = 'Validation loss')
plt.title('Loss vs Validation loss')
# Out:
# Text(0.5, 1.0, 'Loss vs Validation loss')

# %%
import numpy as np


for image_batch, label_batch in test_gen:
    first_image = image_batch[0]
    first_label = int(label_batch[0])
    
    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_names[first_label])
    
    batch_prediction = model.predict(image_batch)
    print("predicted label:",class_names[np.argmax(batch_prediction[0])])
    plt.axis('off')
    
    break
# Out:
# first image to predict
# actual label: okay-samples
# predicted label: okay-samples

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i])
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_gen:
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i])
        
        predicted_class, confidence = predict(model, images[i])
        actual_class = class_names[int(labels[i])] 
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        
        plt.axis("off")
    break

# %%
model.save('Sign_language_classification.h5')

# %%
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
# %matplotlib inline

print("[INFO] evaluating the model...")
plt.figure(figsize=(10,10))
predIdxs = model.predict(test_gen, steps = len(test_gen))
predIdxs = np.argmax(predIdxs, axis=1)
matrix = confusion_matrix(test_gen.classes,predIdxs)
sns.heatmap(matrix, annot=True, cbar=True, fmt='d')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.title('Confusion Matrix')
# Out:
# [INFO] evaluating the model...
# Text(0.5, 1.0, 'Confusion Matrix')
